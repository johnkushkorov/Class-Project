# %%
import pandas as pd
global_temp = pd.read_csv('/Users/ilhomjonkushkorov/Desktop/global_annual_mean_temp_anomalies_land-ocean_1880-2016.csv')
display(global_temp)
# Out:
#      Year     Temp
# 0    1880  13.7852
# 1    1881  13.8372
# 2    1882  13.8352
# 3    1883  13.7576
# 4    1884  13.6991
# 5    1885  13.6875
# 6    1886  13.6997
# 7    1887  13.6511
# 8    1888  13.7529
# 9    1889  13.8018
# 10   1890  13.5780
# 11   1891  13.6468
# 12   1892  13.5938
# 13   1893  13.5788
# 14   1894  13.6192
# 15   1895  13.6710
# 16   1896  13.8026
# 17   1897  13.7776
# 18   1898  13.6454
# 19   1899  13.7827
# 20   1900  13.8321
# 21   1901  13.7583
# 22   1902  13.6537
# 23   1903  13.5631
# 24   1904  13.4806
# 25   1905  13.6069
# 26   1906  13.6826
# 27   1907  13.5294
# 28   1908  13.4604
# 29   1909  13.4739
# ..    ...      ...
# 107  1987  14.2696
# 108  1988  14.2757
# 109  1989  14.1970
# 110  1990  14.3328
# 111  1991  14.3055
# 112  1992  14.1571
# 113  1993  14.1853
# 114  1994  14.2409
# 115  1995  14.3577
# 116  1996  14.2228
# 117  1997  14.4187
# 118  1998  14.5344
# 119  1999  14.3438
# 120  2000  14.3262
# 121  2001  14.4473
# ...

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.plot(global_temp['Year'], global_temp['Temp'])
plt.scatter(global_temp['Year'], global_temp['Temp'])

plt.xlabel('Year') 
plt.ylabel('Temprature')
# Out:
# Text(0,0.5,'Temprature')
